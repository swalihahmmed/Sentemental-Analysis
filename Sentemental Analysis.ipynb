# %% [markdown]
# <a href="https://colab.research.google.com/github/swalihahmmed/Sentemental-Analysis/blob/main/Sentemental%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TASK 1
# Read the sentences and label them manually as: Positive / Negative / Neutral

# %%
#process 1
import pandas as pd

data = {
    "text": [
        "I love cbs",
        "This subject is difficult",
        "I am happy today",
        "I hate homework",
        "The weather is okay"
    ],
        "manual_sentiment": [
        "Positive",
        "Negative",
        "Positive",
        "Negative",
        "Neutral"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                         text manual_sentiment
# 0                 I love cbs         Positive
# 1  This subject is difficult         Negative
# 2           I am happy today         Positive
# 3            I hate homework         Negative
# 4        The weather is okay          Neutral

# %%
#Process 2
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

df['score'] = df['text'].apply(lambda x: sia.polarity_scores(x)['compound'])
df['sentiment'] = df['score'].apply(lambda x:
                                    'Positive' if x > 0
                                    else ('Negative' if x < 0
                                    else 'Neutral'))
df
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                         text manual_sentiment   score sentiment
# 0                 I love cbs         Positive  0.6369  Positive
# 1  This subject is difficult         Negative -0.3612  Negative
# 2           I am happy today         Positive  0.5719  Positive
# 3            I hate homework         Negative -0.5719  Negative
# 4        The weather is okay          Neutral  0.2263  Positive

# %%
#process 3
# !pip install afinn
from afinn import Afinn

af = Afinn()

sentences = ["I love this class", "I hate homework", "This is okay"]
for s in sentences:
    print(s, af.score(s))
# Out:
# Collecting afinn
#   Downloading afinn-0.1.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: afinn
#   Building wheel for afinn (setup.py) ... done
#   Created wheel for afinn: filename=afinn-0.1-py3-none-any.whl size=53431 sha256=a0d218af3625526b20e708d7c87c663a2a5e1e2a2a158dc2948a121167e88fb4
#   Stored in directory: /root/.cache/pip/wheels/f9/72/27/74994e77200dae3d6aea2b546264500cee21f738c51241320b
# Successfully built afinn
# Installing collected packages: afinn
# Successfully installed afinn-0.1
# I love this class 3.0
# I hate homework -3.0
# This is okay 0.0

# %%
#process 4
# !pip install textblob
from textblob import TextBlob

sentences = ["I love this class", "I hate homework", "This is okay"]
for s in sentences:
    blob = TextBlob(s)
    print(s, blob.sentiment)
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.12/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.12/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (4.67.1)
# I love this class Sentiment(polarity=0.5, subjectivity=0.6)
# I hate homework Sentiment(polarity=-0.8, subjectivity=0.9)
# This is okay Sentiment(polarity=0.5, subjectivity=0.5)

# %%
#Let us compare !
from textblob import TextBlob

df['textblob_score'] = df['text'].apply(lambda x: TextBlob(x).sentiment.polarity)
df['textblob_sentiment'] = df['textblob_score'].apply(
    lambda x: 'Positive' if x>0 else ('Negative' if x<0 else 'Neutral')
)
df
# Out:
#                         text   score sentiment  textblob_score  \
# 0                 I love cbs  0.6369  Positive        0.500000
# 1  This subject is difficult -0.3612  Negative       -0.333333
# 2           I am happy today  0.5719  Positive        0.800000
# 3            I hate homework -0.5719  Negative       -0.800000
# 4        The weather is okay  0.2263  Positive        0.500000
#
#   textblob_sentiment
# 0           Positive
# 1           Negative
# 2           Positive
# 3           Negative
# 4           Positive

# %%
import pandas as pd

texts = [
    "I LOVE this movie!!! 😍😍",
    "This course is SO boring... 😴 ",
    "I think AI is amazing 🤖💡",
    "Not sure if I like this. 🤷",
    "Great work!!! Keep it up 🔥🔥"
]

# Create DataFrame
df = pd.DataFrame(texts, columns=["text"])

# Display DataFrame
print(df)
# Out:
#                              text
# 0         I LOVE this movie!!! 😍😍
# 1  This course is SO boring... 😴
# 2        I think AI is amazing 🤖💡
# 3      Not sure if I like this. 🤷
# 4     Great work!!! Keep it up 🔥🔥

# %%
#import pandas as pd
#df = pd.DataFrame(texts, columns=["text"])
#df

# %%
df['clean_text'] = df['text'].str.lower()
df['clean_text'] = df['clean_text'].str.strip()
df[['text','clean_text']]
# Out:
#                              text                     clean_text
# 0         I LOVE this movie!!! 😍😍        i love this movie!!! 😍😍
# 1  This course is SO boring... 😴   this course is so boring... 😴
# 2        I think AI is amazing 🤖💡       i think ai is amazing 🤖💡
# 3      Not sure if I like this. 🤷     not sure if i like this. 🤷
# 4     Great work!!! Keep it up 🔥🔥    great work!!! keep it up 🔥🔥

# %%
import string
df['no_punct'] = df['clean_text'].str.translate(str.maketrans('', '', string.punctuation))
df[['clean_text','no_punct']]
# Out:
#                       clean_text                    no_punct
# 0        i love this movie!!! 😍😍        i love this movie 😍😍
# 1  this course is so boring... 😴  this course is so boring 😴
# 2       i think ai is amazing 🤖💡    i think ai is amazing 🤖💡
# 3     not sure if i like this. 🤷   not sure if i like this 🤷
# 4    great work!!! keep it up 🔥🔥    great work keep it up 🔥🔥

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop = set(stopwords.words('english'))
df['no_stopwords'] = df['no_punct'].apply(lambda x: " ".join([word for word in x.split() if word not in stop]))
df[['no_punct','no_stopwords']]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                      no_punct         no_stopwords
# 0        i love this movie 😍😍        love movie 😍😍
# 1  this course is so boring 😴      course boring 😴
# 2    i think ai is amazing 🤖💡  think ai amazing 🤖💡
# 3   not sure if i like this 🤷          sure like 🤷
# 4    great work keep it up 🔥🔥   great work keep 🔥🔥

# %%
import re

def remove_emojis(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"
                           u"\U0001F300-\U0001F5FF"
                           u"\U0001F680-\U0001F6FF"
                           u"\U0001F1E0-\U0001F1FF"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

df['no_emoji'] = df['no_stopwords'].apply(remove_emojis)
df[['no_stopwords','no_emoji']]
# Out:
#           no_stopwords            no_emoji
# 0        love movie 😍😍         love movie
# 1      course boring 😴      course boring
# 2  think ai amazing 🤖💡  think ai amazing 🤖
# 3          sure like 🤷         sure like 🤷
# 4   great work keep 🔥🔥    great work keep
